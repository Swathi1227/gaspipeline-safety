# %%
#import libraries
import numpy
import pandas
import sklearn
import seaborn
import matplotlib.pyplot as plt
# %matplotlib inline


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,accuracy_score
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets,linear_model
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

#warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Load data in pandas dataframe
hak_df=pandas.read_csv('C:/Users/sys180/Desktop/hakaton.csv')

# %%
hak_df
# Out:
#       id data_file          form_rev  oper_id  report_year    report_num  \
# 0      1  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 1      2  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 2      3  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 3      4  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 4      5  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 5      6  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 6      7  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 7      8  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 8      9  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 9     10  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 10    11  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 11    12  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# ...

# %%
hak_df['failure state'].value_counts()
# Out:
# TX    95
# MO    44
# IN    44
# MA    43
# NJ    23
# TN    19
# AL     8
# GA     6
# MI     5
# NC     3
# HI     3
# OH     2
# FL     2
# NE     1
# VA     1
# AK     1
# Name: failure state, dtype: int64

# %%
#Check if any feature contains missing values
hak_df.isnull().any()
# Out:
# id                  False
# data_file           False
# form_rev            False
# oper_id             False
# report_year         False
# report_num          False
# supp_num            False
# report_type         False
# report_date         False
# filing_date         False
# operator_name       False
# hq_add_city         False
# hq_add_country       True
# hq_add_state        False
# failure state       False
# failure date        False
# mf_type_text        False
# mf_involved_text    False
# leak_loc_a          False
# leak_loc_b          False
# leak_loc_c          False
# year_installed       True
# year_mf              True
# manu_mapped         False
# model_num            True
# leak_cause          False
# damage               True
# leak_occ            False
# mff_num              True
# dtype: bool

# %%
#Now check the count of null value in each feature
hak_df.isnull().sum()
# Out:
# id                    0
# data_file             0
# form_rev              0
# oper_id               0
# report_year           0
# report_num            0
# supp_num              0
# report_type           0
# report_date           0
# filing_date           0
# operator_name         0
# hq_add_city           0
# hq_add_country      210
# hq_add_state          0
# failure state         0
# failure date          0
# mf_type_text          0
# mf_involved_text      0
# leak_loc_a            0
# leak_loc_b            0
# leak_loc_c            0
# year_installed      158
# year_mf             229
# manu_mapped           0
# model_num           217
# leak_cause            0
# damage              299
# leak_occ              0
# mff_num              80
# dtype: int64

# %%
del hak_df['damage']

# %%
del hak_df['hq_add_country']

# %%
#Now check the count of null value in each feature
hak_df.isnull().sum()
# Out:
# id                    0
# data_file             0
# form_rev              0
# oper_id               0
# report_year           0
# report_num            0
# supp_num              0
# report_type           0
# report_date           0
# filing_date           0
# operator_name         0
# hq_add_city           0
# hq_add_state          0
# failure state         0
# failure date          0
# mf_type_text          0
# mf_involved_text      0
# leak_loc_a            0
# leak_loc_b            0
# leak_loc_c            0
# year_installed      158
# year_mf             229
# manu_mapped           0
# model_num           217
# leak_cause            0
# leak_occ              0
# mff_num              80
# dtype: int64

# %%
hak_df['mff_num'].fillna((hak_df[['mff_num']].std()),inplace=True)

# %%
hak_df
# Out:
#       id data_file          form_rev  oper_id  report_year    report_num  \
# 0      1  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 1      2  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 2      3  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 3      4  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 4      5  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 5      6  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 6      7  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 7      8  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 8      9  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 9     10  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 10    11  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 11    12  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# ...

# %%
#Now check the count of null value in each feature
hak_df.isnull().sum()
# Out:
# id                    0
# data_file             0
# form_rev              0
# oper_id               0
# report_year           0
# report_num            0
# supp_num              0
# report_type           0
# report_date           0
# filing_date           0
# operator_name         0
# hq_add_city           0
# hq_add_state          0
# failure state         0
# failure date          0
# mf_type_text          0
# mf_involved_text      0
# leak_loc_a            0
# leak_loc_b            0
# leak_loc_c            0
# year_installed      158
# year_mf             229
# manu_mapped           0
# model_num           217
# leak_cause            0
# leak_occ              0
# mff_num              80
# dtype: int64

# %%
hak_df.groupby(hak_df['year_installed']).mean()
# Out:
#                         id       oper_id  report_year    report_num  \
# year_installed
# 1940.0           21.000000   1209.000000       2018.0  2.020000e+16
# 1951.0          116.000000   9299.500000       2018.0  1.111000e+17
# 1952.0           90.000000   5300.000000       2018.0  2.020000e+16
# 1953.0           91.000000   5300.000000       2018.0  2.020000e+16
# 1958.0          155.500000  15941.500000       2018.0  2.020000e+17
# 1959.0          145.000000  15885.500000       2018.0  2.020000e+17
# 1960.0          149.500000  17993.625000       2018.0  1.792750e+17
# 1961.0          189.000000  19783.333333       2018.0  2.020000e+17
# 1962.0          133.000000  13631.333333       2018.0  1.414000e+17
# 1963.0          175.285714  18568.000000       2018.0  2.020000e+17
# 1964.0          174.285714  18584.000000       2018.0  2.020000e+17
# 1965.0          155.400000  15109.000000       2018.0  1.656400e+17
# 1966.0           85.333333   7839.666667       2018.0  8.080000e+16
# ...

# %%
hak_df['year_installed'].fillna(hak_df['year_installed'].mean(),inplace=True)
hak_df
# Out:
#       id data_file          form_rev  oper_id  report_year    report_num  \
# 0      1  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 1      2  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 2      3  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 3      4  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 4      5  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 5      6  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 6      7  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 7      8  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 8      9  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 9     10  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 10    11  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 11    12  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# ...

# %%
hak_df['year_mf'].fillna(hak_df['year_mf'].mean(),inplace=True)
hak_df
# Out:
#       id data_file          form_rev  oper_id  report_year    report_num  \
# 0      1  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 1      2  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 2      3  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 3      4  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 4      5  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 5      6  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 6      7  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 7      8  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 8      9  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 9     10  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 10    11  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 11    12  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# ...

# %%
#Now check the count of null value in each feature
hak_df.isnull().sum()
# Out:
# id                    0
# data_file             0
# form_rev              0
# oper_id               0
# report_year           0
# report_num            0
# supp_num              0
# report_type           0
# report_date           0
# filing_date           0
# operator_name         0
# hq_add_city           0
# hq_add_state          0
# failure state         0
# failure date          0
# mf_type_text          0
# mf_involved_text      0
# leak_loc_a            0
# leak_loc_b            0
# leak_loc_c            0
# year_installed        0
# year_mf               0
# manu_mapped           0
# model_num           217
# leak_cause            0
# leak_occ              0
# mff_num              80
# dtype: int64

# %%
hak_df['mff_num'].fillna(hak_df['mff_num'].mean(),inplace=True)
hak_df
# Out:
#       id data_file          form_rev  oper_id  report_year    report_num  \
# 0      1  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 1      2  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 2      3  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 3      4  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 4      5  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 5      6  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 6      7  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 7      8  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 8      9  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 9     10  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 10    11  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 11    12  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# ...

# %%
hak_df['year_installed']
# Out:
# 0      1982.000000
# 1      1976.774648
# 2      1975.000000
# 3      1965.000000
# 4      1985.000000
# 5      1966.000000
# 6      1973.000000
# 7      1962.000000
# 8      1983.000000
# 9      1983.000000
# 10     1976.774648
# 11     1991.000000
# 12     1986.000000
# 13     1975.000000
# 14     1966.000000
# 15     1972.000000
# 16     1987.000000
# 17     1976.000000
# 18     1972.000000
# 19     1976.774648
# 20     1940.000000
# 21     1984.000000
# 22     1980.000000
# 23     1987.000000
# 24     1976.774648
# 25     1972.000000
# 26     1972.000000
# 27     1960.000000
# 28     1987.000000
# 29     1987.000000
#           ...
# 270    1976.774648
# 271    1990.000000
# 272    1976.774648
# 273    1976.774648
# 274    1976.774648
# 275    1976.774648
# 276    1976.774648
# 277    1976.774648
# 278    1976.774648
# 279    1976.774648
# 280    1976.774648
# 281    1976.774648
# 282    1976.774648
# 283    1976.774648
# 284    1976.774648
# 285    1976.774648
# ...

# %%
hak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 27 columns):
# id                  300 non-null int64
# data_file           300 non-null object
# form_rev            300 non-null object
# oper_id             300 non-null int64
# report_year         300 non-null int64
# report_num          300 non-null float64
# supp_num            300 non-null int64
# report_type         300 non-null object
# report_date         300 non-null object
# filing_date         300 non-null object
# operator_name       300 non-null object
# hq_add_city         300 non-null object
# hq_add_state        300 non-null object
# failure state       300 non-null object
# failure date        300 non-null object
# mf_type_text        300 non-null object
# mf_involved_text    300 non-null object
# leak_loc_a          300 non-null object
# leak_loc_b          300 non-null object
# leak_loc_c          300 non-null object
# year_installed      300 non-null float64
# ...

# %%
#Now check the count of null value in each feature
hak_df.isnull().sum()
# Out:
# id                    0
# data_file             0
# form_rev              0
# oper_id               0
# report_year           0
# report_num            0
# supp_num              0
# report_type           0
# report_date           0
# filing_date           0
# operator_name         0
# hq_add_city           0
# hq_add_state          0
# failure state         0
# failure date          0
# mf_type_text          0
# mf_involved_text      0
# leak_loc_a            0
# leak_loc_b            0
# leak_loc_c            0
# year_installed        0
# year_mf               0
# manu_mapped           0
# model_num           217
# leak_cause            0
# leak_occ              0
# mff_num               0
# dtype: int64

# %%
del hak_df['model_num']

# %%
hak_df
# Out:
#       id data_file          form_rev  oper_id  report_year    report_num  \
# 0      1  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 1      2  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 2      3  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 3      4  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 4      5  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 5      6  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 6      7  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 7      8  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 8      9  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 9     10  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 10    11  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# 11    12  4/3/2018  7100.1-2 10-2014     1209         2018  2.020000e+16
# ...

# %%
del hak_df['id']

# %%
#Now check the count of null value in each feature
hak_df.isnull().sum()
# Out:
# data_file           0
# form_rev            0
# oper_id             0
# report_year         0
# report_num          0
# supp_num            0
# report_type         0
# report_date         0
# filing_date         0
# operator_name       0
# hq_add_city         0
# hq_add_state        0
# failure state       0
# failure date        0
# mf_type_text        0
# mf_involved_text    0
# leak_loc_a          0
# leak_loc_b          0
# leak_loc_c          0
# year_installed      0
# year_mf             0
# manu_mapped         0
# leak_cause          0
# leak_occ            0
# mff_num             0
# dtype: int64

# %%
#fail_encoder=preprocessing.LabelEncoder()
#fail_encoder.fit(pandas.DataFrame(hak_df['failure state']))

# %%
#hak_df[['failure state']]=fail_encoder.transform(hak_df[['failure state']])

# %%
del hak_df['data_file']

# %%
del hak_df['report_date']

# %%
del hak_df['filing_date']

# %%
del hak_df['report_num']

# %%
del hak_df['form_rev']

# %%
del hak_df['failure date']

# %%
del hak_df['report_year']

# %%
del hak_df['report_type']

# %%
#Take dependent and independent variables seperatly
hak_df_x=hak_df[['oper_id','operator_name','hq_add_city','hq_add_state','mf_type_text','mf_involved_text','leak_loc_a','leak_loc_b','leak_loc_c','year_installed','year_mf','manu_mapped','leak_cause','leak_occ','mff_num']]
hak_df_y=hak_df[['failure state']]

# %%
#divide the data into testing and training. training data is 80% and testing data is 20%
x_train,x_test,y_train,y_test=train_test_split(hak_df_x,hak_df_y,test_size=0.20)

# %%
x_train.head()
# Out:
#      oper_id                       operator_name   hq_add_city hq_add_state  \
# 191    18584      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 94      6243                          HAWAII GAS      HONOLULU           HI
# 189    18584      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 78      2392         CITIZENS GAS & COKE UTILITY  INDIANAPOLIS           IN
# 286    31348  ATMOS ENERGY CORPORATION - MID-TEX        DALLAS           TX
#
#      mf_type_text mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
# ...

# %%
x_train
# Out:
#      oper_id                       operator_name    hq_add_city hq_add_state  \
# 191    18584      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# 94      6243                          HAWAII GAS       HONOLULU           HI
# 189    18584      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# 78      2392         CITIZENS GAS & COKE UTILITY   INDIANAPOLIS           IN
# 286    31348  ATMOS ENERGY CORPORATION - MID-TEX         DALLAS           TX
# 6       1209       COLUMBIA GAS OF MASSACHUSETTS    WESTBOROUGH           MA
# 194    18584      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# 48      2392         CITIZENS GAS & COKE UTILITY   INDIANAPOLIS           IN
# 4       1209       COLUMBIA GAS OF MASSACHUSETTS    WESTBOROUGH           MA
# 146    18124        SAVANNAH PUBLIC UTILITY DEPT       SAVANNAH           TN
# 167    18584      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# ...

# %%
x_train.head()
# Out:
#      oper_id                       operator_name   hq_add_city hq_add_state  \
# 191    18584      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 94      6243                          HAWAII GAS      HONOLULU           HI
# 189    18584      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 78      2392         CITIZENS GAS & COKE UTILITY  INDIANAPOLIS           IN
# 286    31348  ATMOS ENERGY CORPORATION - MID-TEX        DALLAS           TX
#
#      mf_type_text mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
# ...

# %%
#perform Z-score normalization on both 
oper_scaler=StandardScaler()
oper_scaler.fit(pandas.DataFrame(x_train["oper_id"]))
x_train[['oper_id']]=oper_scaler.transform(x_train[['oper_id']])

# %%
x_train
# Out:
#       oper_id                       operator_name    hq_add_city hq_add_state  \
# 191  0.236184      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# 94  -0.804378                          HAWAII GAS       HONOLULU           HI
# 189  0.236184      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# 78  -1.129085         CITIZENS GAS & COKE UTILITY   INDIANAPOLIS           IN
# 286  1.312412  ATMOS ENERGY CORPORATION - MID-TEX         DALLAS           TX
# 6   -1.228833       COLUMBIA GAS OF MASSACHUSETTS    WESTBOROUGH           MA
# 194  0.236184      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# 48  -1.129085         CITIZENS GAS & COKE UTILITY   INDIANAPOLIS           IN
# 4   -1.228833       COLUMBIA GAS OF MASSACHUSETTS    WESTBOROUGH           MA
# 146  0.197398        SAVANNAH PUBLIC UTILITY DEPT       SAVANNAH           TN
# 167  0.236184      SPRINGFIELD, CITY UTILITIES OF    SPRINGFIELD           MO
# ...

# %%
#perform Z-score normalization on both 
year_scaler=StandardScaler()
year_scaler.fit(pandas.DataFrame(x_train["year_installed"]))
x_train[['year_installed']]=year_scaler.transform(x_train[['year_installed']])

# %%
x_train.head()
# Out:
#       oper_id                       operator_name   hq_add_city hq_add_state  \
# 191  0.236184      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 94  -0.804378                          HAWAII GAS      HONOLULU           HI
# 189  0.236184      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 78  -1.129085         CITIZENS GAS & COKE UTILITY  INDIANAPOLIS           IN
# 286  1.312412  ATMOS ENERGY CORPORATION - MID-TEX        DALLAS           TX
#
#      mf_type_text mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
# ...

# %%
#perform Z-score normalization on both 
year1_scaler=StandardScaler()
year1_scaler.fit(pandas.DataFrame(x_train["year_mf"]))
x_train[['year_mf']]=year1_scaler.transform(x_train[['year_mf']])

# %%
x_train.head()
# Out:
#       oper_id                       operator_name   hq_add_city hq_add_state  \
# 191  0.236184      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 94  -0.804378                          HAWAII GAS      HONOLULU           HI
# 189  0.236184      SPRINGFIELD, CITY UTILITIES OF   SPRINGFIELD           MO
# 78  -1.129085         CITIZENS GAS & COKE UTILITY  INDIANAPOLIS           IN
# 286  1.312412  ATMOS ENERGY CORPORATION - MID-TEX        DALLAS           TX
#
#      mf_type_text mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78   NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286  NUT FOLLOWER         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
# ...

# %%
operator_encoder=preprocessing.LabelEncoder()
operator_encoder.fit(pandas.DataFrame(x_train['operator_name']))
# Out:
# LabelEncoder()

# %%
x_train[['operator_name']]=operator_encoder.transform(x_train[['operator_name']])

# %%
x_train.head()
# Out:
#       oper_id  operator_name   hq_add_city hq_add_state  mf_type_text  \
# 191  0.236184             18   SPRINGFIELD           MO  NUT FOLLOWER
# 94  -0.804378              7      HONOLULU           HI  NUT FOLLOWER
# 189  0.236184             18   SPRINGFIELD           MO  NUT FOLLOWER
# 78  -1.129085              2  INDIANAPOLIS           IN  NUT FOLLOWER
# 286  1.312412              0        DALLAS           TX  NUT FOLLOWER
#
#     mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
#      year_installed   year_mf manu_mapped      leak_cause  \
# 191       -0.645624 -0.418265     DRESSER       EQUIPMENT
# ...

# %%
#perform Z-score normalization on both 
operator_scaler=StandardScaler()
operator_scaler.fit(pandas.DataFrame(x_train["operator_name"]))
x_train[['operator_name']]=operator_scaler.transform(x_train[['operator_name']])

# %%
x_train.head()
# Out:
#       oper_id  operator_name   hq_add_city hq_add_state  mf_type_text  \
# 191  0.236184       1.687725   SPRINGFIELD           MO  NUT FOLLOWER
# 94  -0.804378       0.095304      HONOLULU           HI  NUT FOLLOWER
# 189  0.236184       1.687725   SPRINGFIELD           MO  NUT FOLLOWER
# 78  -1.129085      -0.628524  INDIANAPOLIS           IN  NUT FOLLOWER
# 286  1.312412      -0.918055        DALLAS           TX  NUT FOLLOWER
#
#     mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
#      year_installed   year_mf manu_mapped      leak_cause  \
# 191       -0.645624 -0.418265     DRESSER       EQUIPMENT
# ...

# %%
city_encoder=preprocessing.LabelEncoder()
city_encoder.fit(pandas.DataFrame(x_train['hq_add_city']))
# Out:
# LabelEncoder()

# %%
x_train[['hq_add_city']]=city_encoder.transform(x_train[['hq_add_city']])

# %%
x_train.head()
# Out:
#       oper_id  operator_name  hq_add_city hq_add_state  mf_type_text  \
# 191  0.236184       1.687725           15           MO  NUT FOLLOWER
# 94  -0.804378       0.095304            7           HI  NUT FOLLOWER
# 189  0.236184       1.687725           15           MO  NUT FOLLOWER
# 78  -1.129085      -0.628524            8           IN  NUT FOLLOWER
# 286  1.312412      -0.918055            3           TX  NUT FOLLOWER
#
#     mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
#      year_installed   year_mf manu_mapped      leak_cause  \
# 191       -0.645624 -0.418265     DRESSER       EQUIPMENT
# ...

# %%
#perform Z-score normalization on both 
city_scaler=StandardScaler()
city_scaler.fit(pandas.DataFrame(x_train["hq_add_city"]))
x_train[['hq_add_city']]=city_scaler.transform(x_train[['hq_add_city']])

# %%
x_train.head()
# Out:
#       oper_id  operator_name  hq_add_city hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465           MO  NUT FOLLOWER
# 94  -0.804378       0.095304    -0.518495           HI  NUT FOLLOWER
# 189  0.236184       1.687725     0.669465           MO  NUT FOLLOWER
# 78  -1.129085      -0.628524    -0.370000           IN  NUT FOLLOWER
# 286  1.312412      -0.918055    -1.112475           TX  NUT FOLLOWER
#
#     mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
#      year_installed   year_mf manu_mapped      leak_cause  \
# 191       -0.645624 -0.418265     DRESSER       EQUIPMENT
# ...

# %%
state_encoder=preprocessing.LabelEncoder()
state_encoder.fit(pandas.DataFrame(x_train['hq_add_state']))
# Out:
# LabelEncoder()

# %%
x_train[['hq_add_state']]=state_encoder.transform(x_train[['hq_add_state']])

# %%
x_train.head()
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465             9  NUT FOLLOWER
# 94  -0.804378       0.095304    -0.518495             5  NUT FOLLOWER
# 189  0.236184       1.687725     0.669465             9  NUT FOLLOWER
# 78  -1.129085      -0.628524    -0.370000             6  NUT FOLLOWER
# 286  1.312412      -0.918055    -1.112475            15  NUT FOLLOWER
#
#     mf_involved_text   leak_loc_a leak_loc_b        leak_loc_c  \
# 191         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 94          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 189         COUPLING  BELOWGROUND    OUTSIDE        MAINTOMAIN
# 78          COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
# 286         COUPLING  BELOWGROUND    OUTSIDE  SERVICETOSERVICE
#
#      year_installed   year_mf manu_mapped      leak_cause  \
# 191       -0.645624 -0.418265     DRESSER       EQUIPMENT
# ...

# %%
#perform Z-score normalization on both 
state_scaler=StandardScaler()
state_scaler.fit(pandas.DataFrame(x_train["hq_add_state"]))
x_train[['hq_add_state']]=state_scaler.transform(x_train[['hq_add_state']])

# %%
text_encoder=preprocessing.LabelEncoder()
text_encoder.fit(pandas.DataFrame(x_train['mf_type_text']))
# Out:
# LabelEncoder()

# %%
x_train[['mf_type_text']]=text_encoder.transform(x_train[['mf_type_text']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
text1_encoder=preprocessing.LabelEncoder()
text1_encoder.fit(pandas.DataFrame(x_train['mf_involved_text']))
# Out:
# LabelEncoder()

# %%
x_train[['mf_involved_text']]=text1_encoder.transform(x_train[['mf_involved_text']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
#perform Z-score normalization on both 
text1_scaler=StandardScaler()
text1_scaler.fit(pandas.DataFrame(x_train["mf_involved_text"]))
x_train[['mf_involved_text']]=text1_scaler.transform(x_train[['mf_involved_text']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
a_encoder=preprocessing.LabelEncoder()
a_encoder.fit(pandas.DataFrame(x_train['leak_loc_a']))
# Out:
# LabelEncoder()

# %%
x_train[['leak_loc_a']]=a_encoder.transform(x_train[['leak_loc_a']])

# %%
b_encoder=preprocessing.LabelEncoder()
b_encoder.fit(pandas.DataFrame(x_train['leak_loc_b']))
# Out:
# LabelEncoder()

# %%
x_train[['leak_loc_b']]=b_encoder.transform(x_train[['leak_loc_b']])

# %%
c_encoder=preprocessing.LabelEncoder()
c_encoder.fit(pandas.DataFrame(x_train['leak_loc_c']))
# Out:
# LabelEncoder()

# %%
x_train[['leak_loc_c']]=c_encoder.transform(x_train[['leak_loc_c']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
#perform Z-score normalization on both
c_scaler=StandardScaler()
c_scaler.fit(pandas.DataFrame(x_train["leak_loc_c"]))
x_train[['leak_loc_c']]=c_scaler.transform(x_train[['leak_loc_c']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
mf_encoder=preprocessing.LabelEncoder()
mf_encoder.fit(pandas.DataFrame(x_train['manu_mapped']))
# Out:
# LabelEncoder()

# %%
x_train[['manu_mapped']]=mf_encoder.transform(x_train[['manu_mapped']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
#perform Z-score normalization on both
mf_scaler=StandardScaler()
mf_scaler.fit(pandas.DataFrame(x_train["manu_mapped"]))
x_train[['manu_mapped']]=mf_scaler.transform(x_train[['manu_mapped']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
le_encoder=preprocessing.LabelEncoder()
le_encoder.fit(pandas.DataFrame(x_train['leak_cause']))
# Out:
# LabelEncoder()

# %%
x_train[['leak_cause']]=le_encoder.transform(x_train[['leak_cause']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
#perform Z-score normalization on both
le_scaler=StandardScaler()
le_scaler.fit(pandas.DataFrame(x_train["leak_cause"]))
x_train[['leak_cause']]=le_scaler.transform(x_train[['leak_cause']])

# %%
le1_encoder=preprocessing.LabelEncoder()
le1_encoder.fit(pandas.DataFrame(x_train['leak_occ']))
# Out:
# LabelEncoder()

# %%
x_train[['leak_occ']]=le1_encoder.transform(x_train[['leak_occ']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
mff_encoder=preprocessing.LabelEncoder()
mff_encoder.fit(pandas.DataFrame(x_train['mff_num']))
# Out:
# LabelEncoder()

# %%
x_train[['mff_num']]=mff_encoder.transform(x_train[['mff_num']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
#perform Z-score normalization on both
mff_scaler=StandardScaler()
mff_scaler.fit(pandas.DataFrame(x_train["mff_num"]))
x_train[['mff_num']]=mff_scaler.transform(x_train[['mff_num']])

# %%
x_train
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 191  0.236184       1.687725     0.669465     -0.233092             1
# 94  -0.804378       0.095304    -0.518495     -1.197608             1
# 189  0.236184       1.687725     0.669465     -0.233092             1
# 78  -1.129085      -0.628524    -0.370000     -0.956479             1
# 286  1.312412      -0.918055    -1.112475      1.213684             1
# 6   -1.228833      -0.483758     1.560434     -0.715350             1
# 194  0.236184       1.687725     0.669465     -0.233092             1
# 48  -1.129085      -0.628524    -0.370000     -0.956479             0
# 4   -1.228833      -0.483758     1.560434     -0.715350             1
# 146  0.197398       1.253429     0.520970      0.972554             1
# 167  0.236184       1.687725     0.669465     -0.233092             1
# 164  0.236184       1.687725     0.669465     -0.233092             1
# ...

# %%
x_test
# Out:
#      oper_id                       operator_name      hq_add_city  \
# 288    31348  ATMOS ENERGY CORPORATION - MID-TEX           DALLAS
# 134    13299           NEW JERSEY NATURAL GAS CO             WALL
# 119    12342  MEMPHIS LIGHT GAS & WATER DIVISION          MEMPHIS
# 97      6790     GREENVILLE UTILITIES COMMISSION       GREENVILLE
# 248    31348  ATMOS ENERGY CORPORATION - MID-TEX           DALLAS
# 153    18472            SEMCO ENERGY GAS COMPANY       PORT HURON
# 197    18584      SPRINGFIELD, CITY UTILITIES OF      SPRINGFIELD
# 285    31348  ATMOS ENERGY CORPORATION - MID-TEX           DALLAS
# 22      1209       COLUMBIA GAS OF MASSACHUSETTS      WESTBOROUGH
# 115    12342  MEMPHIS LIGHT GAS & WATER DIVISION          MEMPHIS
# 155    18584      SPRINGFIELD, CITY UTILITIES OF      SPRINGFIELD
# 174    18584      SPRINGFIELD, CITY UTILITIES OF      SPRINGFIELD
# 24      1209       COLUMBIA GAS OF MASSACHUSETTS      WESTBOROUGH
# ...

# %%
mff_encoder=preprocessing.LabelEncoder()
mff_encoder.fit(pandas.DataFrame(x_test['mff_num']))
# Out:
# LabelEncoder()

# %%
x_test[['mff_num']]=mff_encoder.transform(x_test[['mff_num']])

# %%
#perform Z-score normalization on both
mff_scaler=StandardScaler()
mff_scaler.fit(pandas.DataFrame(x_test["mff_num"]))
x_test[['mff_num']]=mff_scaler.transform(x_test[['mff_num']])

# %%
#perform Z-score normalization on both 
oper_scaler=StandardScaler()
oper_scaler.fit(pandas.DataFrame(x_test["oper_id"]))
x_test[['oper_id']]=oper_scaler.transform(x_test[['oper_id']])

# %%
#perform Z-score normalization on both 
year_scaler=StandardScaler()
year_scaler.fit(pandas.DataFrame(x_test["year_installed"]))
x_test[['year_installed']]=year_scaler.transform(x_test[['year_installed']])

# %%
#perform Z-score normalization on both 
year1_scaler=StandardScaler()
year1_scaler.fit(pandas.DataFrame(x_test["year_mf"]))
x_test[['year_mf']]=year1_scaler.transform(x_test[['year_mf']])

# %%
operator_encoder=preprocessing.LabelEncoder()
operator_encoder.fit(pandas.DataFrame(x_test['operator_name']))
# Out:
# LabelEncoder()

# %%
x_test[['operator_name']]=operator_encoder.transform(x_test[['operator_name']])

# %%
#perform Z-score normalization on both 
operator_scaler=StandardScaler()
operator_scaler.fit(pandas.DataFrame(x_test["operator_name"]))
x_test[['operator_name']]=operator_scaler.transform(x_test[['operator_name']])

# %%
city_encoder=preprocessing.LabelEncoder()
city_encoder.fit(pandas.DataFrame(x_test['hq_add_city']))
# Out:
# LabelEncoder()

# %%
x_test[['hq_add_city']]=city_encoder.transform(x_test[['hq_add_city']])

# %%
#perform Z-score normalization on both 
city_scaler=StandardScaler()
city_scaler.fit(pandas.DataFrame(x_test["hq_add_city"]))
x_test[['hq_add_city']]=city_scaler.transform(x_test[['hq_add_city']])

# %%
state_encoder=preprocessing.LabelEncoder()
state_encoder.fit(pandas.DataFrame(x_test['hq_add_state']))
# Out:
# LabelEncoder()

# %%
x_test[['hq_add_state']]=state_encoder.transform(x_test[['hq_add_state']])

# %%
#perform Z-score normalization on both 
state_scaler=StandardScaler()
state_scaler.fit(pandas.DataFrame(x_test["hq_add_state"]))
x_test[['hq_add_state']]=state_scaler.transform(x_test[['hq_add_state']])

# %%
text_encoder=preprocessing.LabelEncoder()
text_encoder.fit(pandas.DataFrame(x_test['mf_type_text']))
# Out:
# LabelEncoder()

# %%
x_test[['mf_type_text']]=text_encoder.transform(x_test[['mf_type_text']])

# %%
text1_encoder=preprocessing.LabelEncoder()
text1_encoder.fit(pandas.DataFrame(x_test['mf_involved_text']))
# Out:
# LabelEncoder()

# %%
x_test[['mf_involved_text']]=text1_encoder.transform(x_test[['mf_involved_text']])

# %%
#perform Z-score normalization on both 
text1_scaler=StandardScaler()
text1_scaler.fit(pandas.DataFrame(x_test["mf_involved_text"]))
x_test[['mf_involved_text']]=text1_scaler.transform(x_test[['mf_involved_text']])

# %%
a_encoder=preprocessing.LabelEncoder()
a_encoder.fit(pandas.DataFrame(x_test['leak_loc_a']))
# Out:
# LabelEncoder()

# %%
x_test[['leak_loc_a']]=a_encoder.transform(x_test[['leak_loc_a']])

# %%
b_encoder=preprocessing.LabelEncoder()
b_encoder.fit(pandas.DataFrame(x_test['leak_loc_b']))
# Out:
# LabelEncoder()

# %%
x_test[['leak_loc_b']]=b_encoder.transform(x_test[['leak_loc_b']])

# %%
c_encoder=preprocessing.LabelEncoder()
c_encoder.fit(pandas.DataFrame(x_test['leak_loc_c']))
# Out:
# LabelEncoder()

# %%
x_test[['leak_loc_c']]=c_encoder.transform(x_test[['leak_loc_c']])

# %%
#perform Z-score normalization on both
c_scaler=StandardScaler()
c_scaler.fit(pandas.DataFrame(x_test["leak_loc_c"]))
x_test[['leak_loc_c']]=c_scaler.transform(x_test[['leak_loc_c']])

# %%
mf_encoder=preprocessing.LabelEncoder()
mf_encoder.fit(pandas.DataFrame(x_test['manu_mapped']))
# Out:
# LabelEncoder()

# %%
x_test[['manu_mapped']]=mf_encoder.transform(x_test[['manu_mapped']])

# %%
#perform Z-score normalization on both
mf_scaler=StandardScaler()
mf_scaler.fit(pandas.DataFrame(x_test["manu_mapped"]))
x_test[['manu_mapped']]=mf_scaler.transform(x_test[['manu_mapped']])

# %%
le_encoder=preprocessing.LabelEncoder()
le_encoder.fit(pandas.DataFrame(x_test['leak_cause']))
# Out:
# LabelEncoder()

# %%
x_test[['leak_cause']]=le_encoder.transform(x_test[['leak_cause']])

# %%
#perform Z-score normalization on both
le_scaler=StandardScaler()
le_scaler.fit(pandas.DataFrame(x_test["leak_cause"]))
x_test[['leak_cause']]=le_scaler.transform(x_test[['leak_cause']])

# %%
le1_encoder=preprocessing.LabelEncoder()
le1_encoder.fit(pandas.DataFrame(x_test['leak_occ']))
# Out:
# LabelEncoder()

# %%
x_test[['leak_occ']]=le1_encoder.transform(x_test[['leak_occ']])

# %%
mff_encoder=preprocessing.LabelEncoder()
mff_encoder.fit(pandas.DataFrame(x_test['mff_num']))
# Out:
# LabelEncoder()

# %%
x_test[['mff_num']]=mff_encoder.transform(x_test[['mff_num']])

# %%
#perform Z-score normalization on both
mff_scaler=StandardScaler()
mff_scaler.fit(pandas.DataFrame(x_test["mff_num"]))
x_test[['mff_num']]=mff_scaler.transform(x_test[['mff_num']])

# %%
x_test
# Out:
#       oper_id  operator_name  hq_add_city  hq_add_state  mf_type_text  \
# 288  1.049611      -0.894306    -1.017814      0.900031             1
# 134 -0.497595       1.149821     1.026331      0.155178             1
# 119 -0.579632       0.894306     0.259777      0.527604             1
# 97  -1.055563       0.383274    -0.506778     -0.217249             0
# 248  1.049611      -0.894306    -1.017814      0.900031             0
# 153 -0.054152       1.405337     0.515295     -0.962102             1
# 197 -0.044551       1.660853     0.770813     -0.589676             1
# 285  1.049611      -0.894306    -1.017814      0.900031             1
# 22  -1.533981      -0.383274     1.537368     -1.334529             1
# 115 -0.579632       0.894306     0.259777      0.527604             1
# 155 -0.044551       1.660853     0.770813     -0.589676             1
# 174 -0.044551       1.660853     0.770813     -0.589676             1
# ...

# %%
#create objects of logistic regression
logistic_regression=LogisticRegression()

# %%
logistic_regression.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#predicting the logistic data
y_pred=logistic_regression.predict(x_test)

# %%
y_pred
# Out:
# array(['TX', 'NJ', 'MO', 'IN', 'TX', 'HI', 'MO', 'TX', 'MA', 'TN', 'MO',
#        'MO', 'MA', 'TX', 'TX', 'NJ', 'TX', 'TX', 'TX', 'TX', 'IN', 'TX',
#        'MA', 'TN', 'TX', 'MA', 'TN', 'TX', 'TX', 'NJ', 'TX', 'MA', 'TX',
#        'TN', 'TX', 'MA', 'TX', 'MO', 'TN', 'MO', 'MO', 'MI', 'NJ', 'IN',
#        'TX', 'TX', 'TX', 'MA', 'MO', 'MA', 'TX', 'TX', 'TN', 'MA', 'TX',
#        'TX', 'TX', 'AL', 'MA', 'IN'], dtype=object)

# %%
#finding the accuracy of the logistic data
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9166666666666666

# %%
#creating the object of decision tree
decision_tree=tree.DecisionTreeClassifier()

# %%
decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#check on test data
y_pred=decision_tree.predict(x_test)
y_pred_prob=decision_tree.predict_proba(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.21666666666666667

# %%
#build the model using naive bayes on the same data

naive_bayes=GaussianNB()
naive_bayes.fit(x_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#predicting the accuracy using naivebayes
y_pred=naive_bayes.predict(x_test)
y_pred_prob=naive_bayes.predict_proba(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6666666666666666

# %%
#WE will build random forest on the same dataset

random_forest=RandomForestClassifier()
random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#predicting the accuracy using random forest
y_pred=random_forest.predict(x_test)
y_pred_prob=random_forest.predict_proba(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.8166666666666667
